# %% [markdown]
# # Домашнее задание 5.2

# %% [markdown]
# # ✏️ 🗒️ 📝
#
# Сегодня тебе нужно выполнить задачу от руководительницы отдела контент-маркетинга новой онлайн-школы английского языка. Она хочет составить ТЗ копирайтеру на написание постов, но для этого ей нужно знать, какие типы постов популярны. За завтраком вы с ней обсуждали твое последнее занятие с курса Python, где мы парсили страницы сообществ ВК, и у вас появилась идея – проанализировать самые успешные посты известной онлайн-школы Skyeng  в [сообществе Skyeng в ВК](https://vk.com/skyeng).
#
# Теперь перед тобой стоит задача – выгрузить маркетологам для анализа 50 самых популярных постов за все время существования сообщества. Метрику популярности будем считать как сумму лайков, репостов и комментариев к каждому посту. Если останется время, для дополнительного анализа выгрузи все комментарии к этим постам в отдельный файл.

# %% [markdown]
# ## Задание 1
#
# Получи собственный `access_token` в ВК. Важно пройти этот путь самостоятельно, можешь использовать документацию API ВК или рекомендации из ноутбука занятия.  Токен присылай вместе с файлом ноутбука в файле с именем `my_own_token.py`. Обещаем не делать ничего противозаконного.
#
# *Если тебе некомфортно, можешь не присылать токен нам. Однако получить его все же обязательно – это необходимо для полноценного освоения темы урока, а также для выполнения заданий ниже.*

# %%
# читаем токен из файла my_own_token.py, куда мы сохранили access_token
from my_own_token import my_own_token as token

# %% [markdown]
# ## Задание 2
#
# __Сформируй запрос, который получает 100 записей со стены сообщества__
#
# 1. Найди в документации метод, который отдает все записи со стены сообщества Skyeng: https://vk.com/skyeng
# 2. Создай переменую для URL
# 3. Создай переменную с параметрами
# 4. Создай переменную запроса
# 5. Создай переменную, в которой будут данные ответа в формате словаря

# %%
import requests 
import pandas as pd
import time
import requests
import json

# %%
url = 'https://api.vk.com/method/wall.get'

params = {
    'access_token': token,
#    'group_id': '151933118',
#    'group_id': '51890028', 
    'owner_id': '-' + str('51890028'),   
    'v':'5.103',
    'filter': 'all',
    'count': 100      
        }
req = requests.get(url, params=params)
res = req.json()

print('Кол-во записей:', len(pd.DataFrame(res['response'])))
# Out:
# Кол-во записей: 100
# {'response': {'count': 8162,
#   'items': [{'id': 88838,
#     'from_id': -51890028,
#     'owner_id': -51890028,
#     'date': 1657723336,
#     'marked_as_ads': 0,
#     'is_favorite': False,
#     'post_type': 'post',
#     'text': 'Ваш гороскоп говорит, что сегодня отличный день, чтобы выучить пару английских слов. Выбирайте свой знак (или не свой, мы же не следим) и расширяйте словарный запас. \n \nЕщё звезды попросили передать, что учить английский не так уж сложно, если делать это вместе с нашим бесплатным курсом Easy English. \n \nНа курсе разберем все навыки для эффективного изучения языка — от motivation до speaking — в формате коротких видеоуроков, полезных материалов и домашних заданий. \n \nКак попасть: напишите в [https://vk.me/skyeng|сообщения группы] секретное слово ИЗИ, и мы отправим ссылку :)',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1657720826,
#        'id': 457281886,
#        'owner_id': -51890028,
#        'access_key': 'd24d0b6efd1b56b8c5',
#        'sizes': [{'height': 75,
#          'url': 'https://sun1-28.userapi.com/impg/f-Xk6t72YXMPVSc_8sFhLm2_I9FcnlUtszIu5Q/ORFOhbsi5WI.jpg?size=60x75&quality=95&sign=f7a3f05036e5bcd59f3a05e42a621593&c_uniq_tag=z9DVX-wL2Ao3J8h_YN1GvEKXDoTtQ_ZfBaIVkWilshk&type=album',
#          'type': 's',
#          'width': 60},
#         {'height': 130,
#          'url': 'https://sun1-28.userapi.com/impg/f-Xk6t72YXMPVSc_8sFhLm2_I9FcnlUtszIu5Q/ORFOhbsi5WI.jpg?size=104x130&quality=95&sign=1187ef84bee3b1ec646e03c97998a1eb&c_uniq_tag=aypPlwiGZLgc8kV16m2yvqs00c8IC86XhsOmOhMhqiE&type=album',
#          'type': 'm',
#          'width': 104},
#         {'height': 604,
#          'url': 'https://sun1-28.userapi.com/impg/f-Xk6t72YXMPVSc_8sFhLm2_I9FcnlUtszIu5Q/ORFOhbsi5WI.jpg?size
type=album',
#          'type': 'p',
#          'width': 200},
#         {'height': 400,
#          'url': 'https://sun1-27.userapi.com/impg/uKkox24koLu-4mmt00m1tNe20AaZXqB4WmP9Jg/GX8o5AsEElU.jpg?size=320x400&quality=95&sign=313652e3fb54c13ba5dc861855d4c699&c_uniq_tag=Fu3dzOpX2oDI0ulhD6T-02j5kc-4d7TbpmxWS9AC9-w&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 637,
#          'url': 'https://sun1-27.userapi.com/impg/uKkox24koLu-4mmt00m1tNe20AaZXqB4WmP9Jg/GX8o5AsEElU.jpg?size=510x637&quality=95&sign=f3b400c34524b4498f7d97b1881f47e1&c_uniq_tag=O5St0QqfOLqjhk6FW6hKDqRAU3B_Y2lboP_pJghabcQ&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 8, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 146, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 55, 'user_reposted': 0},
#     'views': {'count': 14601},
#     'hash': 'Lclgutl8YtYmY9nia7fjr-WW7G8'},
#    {'id': 88783,
#     'from_id': -51890028,
#     'owner_id': -51890028,
#     'date': 1657558914,
#     'marked_as_ads': 0,
#     'is_favorite': False,
#     'post_type': 'post',
#     'text': 'Совсем недавно вышел сериал Оби Ван Кеноби. Поэтому пора разобраться, что нужно, что бы говорить на языке Звездных Войн: есть разные интересные нюансы. Например, как Магистр Йода формулирует предложения и почему персонаж Джа Джа Бинкса расистский. \n \nГайд: как учить английский по фильмам и сериалам эффективно: go.skyeng.ru/sw_plan_vk',
#     'attachments': [{'type': 'video',
#       'video': {'access_key': '1bb042d76e29440255',
#        'can_comment': 1,
#        'can_like': 1,
#        'can_repost': 1,
#        'can_subscribe': 1,
#        'can_add_to_faves': 1,
#        'can_add': 1,
#        'comments': 0,
#        'date': 1657558429,
#        'description': 'Совсем недавно вышел сериал Оби Ван Кеноби. Поэтому пора разобраться, что нужно, что бы говорить на языке Звездных Войн: есть разные интересные нюансы. Например, как Магистр Йода формулирует предложения и почему персонаж Джа Джа Бинкса расистский. \n\nГайд: как учить английский по фильмам и сериалам эффективно: go.skyeng.ru/sw_plan_videovk',
#        'duration': 1261,
#        'image': [{'url': 'https://sun1-99.userapi.com/shedUkZDA2RiID1JVWZZHmEG7FlVXNA0q38Ygw/WjKekLGxyWc.jpg',
#          'width': 130,
#          'height': 96,
#          'with_padding': 1},
#         {'url': 'https://sun1-96.userapi.com/yWI-dWI-9MAo6WZKdBz1OPh5scEFoKbKQu3rWQ/6lGo9V8jPM8.jpg',
#          'width': 160,
#          'height': 120,
#          'with_padding': 1},
#         {'url': 'https://sun1-83.userapi.com/P43aF-A2m4mHdN9FLuHB102TVyWH0XWV6gacKQ/rtyhEiqxGHE.jpg',
#          'width': 320,
#          'height': 240,
#          'with_padding': 1},
#         {'url': 'https://sun1-27.userapi.com/I8Hqx3yln7o_AV2ypthMHmPJdnwxdlGsfBEp1Q/KXuepnZWnlc.jpg',
#          'width': 800,
#          'height': 450,
#          'with_padding': 1},
#         {'url': 'https://sun1-91.userapi.com/rA7agyuvfiCekqSaA2ljBKbd0XBPTNEnzOOqhQ/vZCwc1V1oxo.jpg',
#          'width': 1280,
#          'height': 720},
#         {'url': 'https://sun1-98.userapi.com/HTw_KUBfHE1Mqpwxy85AH02rSakeh3DKyViImA/l8TPxKPj0EE.jpg',
#          'width': 320,
#          'height': 180},
#         {'url': 'https://sun1-25.userapi.com/RIdaQ_zyCUapl0kSHxfNzeZFSeoU5tPGo9zjOQ/MjU07mDr1s4.jpg',
#          'width': 720,
#          'height': 405},
#         {'url': 'https://sun1-20.userapi.com/pIZuIePit9oFktuPcS_umTCdaL0leODbkaFlxA/7iJBG6tPye8.jpg',
#          'width': 1024,
#          'height': 576},
#         {'url': 'https://sun1-91.userapi.com/B3L9RuyU0h4VuBUQz-kRxSlFxs9tGeOoPmRnGA/2QfGkmVNAo0.jpg',
#          'width': 4096,
#          'height': 2304}],
#        'first_frame': [{'url': 'https://i.mycdn.me/getVideoPreview?id=2719763729014&idx=0&type=39&tkn=8qmPnRKkPin83FvhJ7r8WW5QRsY&fn=vid_f',
#          'width': 720,
#          'height': 405},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2719763729014&idx=0&type=39&tkn=8qmPnRKkPin83FvhJ7r8WW5QRsY&fn=vid_md',
#          'width': 480,
#          'height': 270},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2719763729014&idx=0&type=39&tkn=8qmPnRKkPin83FvhJ7r8WW5QRsY&fn=vid_d',
#          'width': 240,
#          'height': 135},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2719763729014&idx=0&type=39&tkn=8qmPnRKkPin83FvhJ7r8WW5QRsY&fn=vid_sm',
#          'width': 128,
#          'height': 72},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2719763729014&idx=0&type=39&tkn=8qmPnRKkPin83FvhJ7r8WW5QRsY',
#          'width': 1280,
#          'height': 720},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2719763729014&idx=0&type=39&tkn=8qmPnRKkPin83FvhJ7r8WW5QRsY&fn=vid_h',
#          'width': 960,
#          'height': 540},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2719763729014&idx=0&type=39&tkn=8qmPnRKkPin83FvhJ7r8WW5QRsY',
#          'width': 1280,
#          'height': 720}],
#        'width': 3840,
#        'height': 2160,
#        'id': 456240428,
#        'owner_id': -51890028,
#        'title': 'Что вы не заметили в Звездных войнах из-за дубляжа? Английский Оби-Вана Кеноби, Вейдера, Йоды',
#        'is_favorite': False,
#        'track_code': 'video_2e10fa3fjG188Vp0vdh-EiQ-wbBZntilaGDT2Z3HzGAOnSTHdqy2TmH2UxO80HkYL2H1hW-s7JVcUuvd6qagDA',
#        'type': 'video',
#        'views': 6295}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 0, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 16, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 13, 'user_reposted': 0},
#     'views': {'count': 6553},
#     'hash': 'akwkIDTD8i9NLuzvz7bM70DH23E'},
#    {'id': 88759,
#     'from_id': -51890028,
#     'owner_id': -51890028,
#     'date': 1657438405,
#     'marked_as_ads': 0,
#     'is_favorite': False,
#     'post_type': 'post',
#     'text': '',
#     'attachments': [{'type': 'video',
#       'video': {'can_comment': 1,
#        'can_like': 1,
#        'can_repost': 1,
#        'can_subscribe': 1,
#        'can_add_to_faves': 1,
#        'can_add': 0,
#        'comments': 13,
#        'date': 1657438405,
#        'description': 'Чтобы не бояться таких ситуаций, пользуйтесь нашим личным планом по фильмам и сериалам. Напишите нам «Хочу учить язык по фильмам» и получите ссылку #skyeng #английскийпофильмам #клипызнания',
#        'duration': 33,
#        'image': [{'url': 'https://sun1-14.userapi.com/Z2pME9zscIq-iV4QZcWuhRbU4-hwqAcs3CDjig/OgPq1jezT_o.jpg',
#          'width': 130,
#          'height': 96,
#          'with_padding': 1},
#         {'url': 'https://sun1-20.userapi.com/KArm9EdB3hU-aWt4ExnoJz2GoZ0xu-zT71SJdw/4O4gN_84Wts.jpg',
#          'width': 160,
#          'height': 120,
#          'with_padding': 1},
#         {'url': 'https://sun1-26.userapi.com/2MScb4APwCrgFCF_853HkM1GGf18pMfkJM2frw/1dYhX-h7oUo.jpg',
#          'width': 320,
#          'height': 240,
#          'with_padding': 1},
#         {'url': 'https://sun1-16.userapi.com/TmN9_XfqQUVvstCdGbxFROIlw6ZgVRkQO7AhMw/zHv3FPUTPy4.jpg',
#          'width': 800,
#          'height': 450,
#          'with_padding': 1},
#         {'url': 'https://sun1-57.userapi.com/DGV5EhcRhetjr7KCeGJpFWVkJYdrfETEKfmCGg/kB2dDXop8Oo.jpg',
#          'width': 405,
#          'height': 720},
#         {'url': 'https://sun1-30.userapi.com/3fhHs95m3nFT4vkjmacEGj6BCSFAaF_Syh53_A/xW8CIFZx_FE.jpg',
#          'width': 320,
#          'height': 569},
#         {'url': 'https://sun1-22.userapi.com/ySEO8QAvEFzLQ7jWTSkbASQOE1Qn6GR_LHr85Q/W07IJep5Sxo.jpg',
#          'width': 720,
#          'height': 1280},
#         {'url': 'https://sun1-23.userapi.com/5JCEWUzOX5o9YCu2uA3z0uqJKk0vm3XU6awubA/cl3GN3-Ux-o.jpg',
#          'width': 1024,
#          'height': 1820},
#         {'url': 'https://sun1-96.userapi.com/f90Pg1TGNu2mJN6G0eIP825bEkxVlkblH8XO3w/rO6KDnOWx2c.jpg',
#          'width': 2304,
#          'height': 4096}],
#        'first_frame': [{'url': 'https://i.mycdn.me/getVideoPreview?id=2640154659337&idx=0&type=39&tkn=36AdGMRfawq1cxf8bUh3VhcmGlE&fn=vid_f',
#          'width': 405,
#          'height': 720},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2640154659337&idx=0&type=39&tkn=36AdGMRfawq1cxf8bUh3VhcmGlE&fn=vid_md',
#          'width': 270,
#          'height': 480},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2640154659337&idx=0&type=39&tkn=36AdGMRfawq1cxf8bUh3VhcmGlE&fn=vid_d',
#          'width': 135,
#          'height': 240},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2640154659337&idx=0&type=39&tkn=36AdGMRfawq1cxf8bUh3VhcmGlE&fn=vid_sm',
#          'width': 72,
#          'height': 128},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2640154659337&idx=0&type=39&tkn=36AdGMRfawq1cxf8bUh3VhcmGlE&fn=vid_h',
#          'width': 540,
#          'height': 960},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2640154659337&idx=0&type=39&tkn=36AdGMRfawq1cxf8bUh3VhcmGlE',
#          'width': 720,
#          'height': 1280}],
#        'width': 1080,
#        'height': 1920,
#        'id': 456240424,
#        'owner_id': -51890028,
#        'title': 'Клип @skyeng',
#        'is_favorite': False,
#        'track_code': 'video_427fb919eiSFWHOKSDWuNB44GOiE06yHQUn205g_QjCZ2x_Qp-xAB5hfeu1JPakzH2cs3bLhmLd1e8LX714uXA',
#        'repeat': 1,
#        'type': 'short_video',
#        'views': 15603}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 13, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 30, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 7, 'user_reposted': 0},
#     'views': {'count': 11929},
#     'hash': 'CBJUmCYHmw9lcO4fbgGrIUShiCI'},
#    {'id': 88752,
#     'from_id': -51890028,
#     'owner_id': -51890028,
#     'date': 1657387800,
#     'marked_as_ads': 0,
#     'is_favorite': False,
#     'post_type': 'post',
#     'text': 'Среда — потому что в середине недели. Пятница — потому что пятый день. В русском все понятно (хотя, конечно, к субботе у нас есть вопросы). А вот в английском — ничего не понятно. Разбираемся, откуда пришли названия дней недели, и рассказываем, как перестать путать Tuesday и Thursday, Saturday и Sunday!\n\nВсех тонкостей и интересных историй про английский в один пост не уместишь. А вот в индивидуальные занятия — вполне. Начните заниматься английским с нами: это не только интересно и крайне удобно, но еще и с огромной скидкой до 12 июля. За подробностями — по ссылке: https://go.skyeng.ru/final_summer_sale',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 
type=album',
#          'type': 'o',
#          'width': 130},
#         {'height': 250,
#          'url': 'https://sun9-84.userapi.com/impg/GdZEN7sROdwVRY8LRWaxjb_aZIRumlmPZ1g8Iw/zEne-5-OO_U.jpg?size=200x250&quality=95&sign=07b028900348fd92e6ebfbceccada1f6&c_uniq_tag=dA_yM6EQ1Nd5ht0QXN8QmRjteCeWAcO5xYtEA-mCfmM&type=album',
#          'type': 'p',
#          'width': 200},
#         {'height': 400,
#          'url': 'https://sun9-84.userapi.com/impg/GdZEN7sROdwVRY8LRWaxjb_aZIRumlmPZ1g8Iw/zEne-5-OO_U.jpg?size=320x400&quality=95&sign=a7a340df3794d31ac20727d0ffa1edf0&c_uniq_tag=JutaB9MeL5ZghSnTO4yneIJd-tiEQp_MsOdtjfF60rY&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 637,
#          'url': 'https://sun9-84.userapi.com/impg/GdZEN7sROdwVRY8LRWaxjb_aZIRumlmPZ1g8Iw/zEne-5-OO_U.jpg?size=510x637&quality=95&sign=6e4c54afe91b67280ca6a66fd57df25e&c_uniq_tag=rFqzL-WO_PcQhItpmIDwAbZ1fec_V6HdFjjfG8sBVoQ&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 3, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 7, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 6, 'user_reposted': 0},
#     'views': {'count': 34986},
#     'edited': 1651853908,
#     'hash': 'hESmoMa038m--WLU2Kf0PgigmRk'},
#    {'id': 87080,
#     'from_id': -51890028,
#     'owner_id': -51890028,
#     'date': 1651837406,
#     'marked_as_ads': 0,
#     'is_favorite': False,
#     'post_type': 'post',
#     'text': 'На русском слова в предложении можно ставить как угодно — грамматически все будет верно. Но в английском так нельзя. Здесь порядок слов в предложении четко пронумерован. И вот вам лайфхак, чтобы его запомнить: SVOMPT. \n \nЕще больше полезной, нескучной и несложной информации об изучении английского — у нас на «Леньтенсиве». За 10 дней расскажем 10 лайфхаков, как сделать новый язык частью своей жизни: go.skyeng.ru/lazyness_post_vk \nЭто бесплатно. \n \nИ держите удобную шпаргалку по SVOMPT, чтобы не забыть пройденный в видео материал: go.skyeng.ru/svompt_vk',
#     'attachments': [{'type': 'video',
#       'video': {'access_key': 'acbc46f12792d65a33',
#        'can_comment': 1,
#        'can_like': 1,
#        'can_repost': 1,
#        'can_subscribe': 1,
#        'can_add_to_faves': 1,
#        'can_add': 1,
#        'comments': 2,
#        'date': 1651826463,
#        'description': 'На русском слова в предложении можно ставить как угодно — грамматически все будет верно. Но в английском так нельзя. Здесь порядок слов в предложении четко пронумерован. И вот вам лайфхак, чтобы его запомнить: SVOMPT.\n\nЕще больше полезной, нескучной и несложной информации об изучении английского — у нас на «Леньтенсиве». За 10 дней расскажем 10 лайфхаков, как сделать новый язык частью своей жизни: go.skyeng.ru/lazyness_video-vk\nЭто бесплатно. \n\nИ держите удобную шпаргалку по SVOMPT, чтобы не забыть пройденный в видео материал: go.skyeng.ru/svompt_video_vk',
#        'duration': 392,
#        'image': [{'url': 'https://sun1-95.userapi.com/Mm1WrAP4e7EMpxOgnTyAaYQ1eh4060Md4hslyw/2iSPaJ_J1kw.jpg',
#          'width': 130,
#          'height': 96,
#          'with_padding': 1},
#         {'url': 'https://sun1-83.userapi.com/axfbWFepEn41mZoriRkVox-_XsPjcbfNuVxj8Q/pn1Kr7k4UaM.jpg',
#          'width': 160,
#          'height': 120,
#          'with_padding': 1},
#         {'url': 'https://sun1-21.userapi.com/dvlKUNSpRVfCcQEcnimdKARjnxcUGkHX82uuIA/sPAC6PGWrFc.jpg',
#          'width': 320,
#          'height': 240,
#          'with_padding': 1},
#         {'url': 'https://sun1-15.userapi.com/05b3mESs0zDz9MPSj6Ueh7-TBrYX2nSSa60FLQ/wQ8ZQDVee4c.jpg',
#          'width': 800,
#          'height': 450,
#          'with_padding': 1},
#         {'url': 'https://sun1-14.userapi.com/214ThWX1GXsW2nkIXQY--bGoFgeyC_Mo7dlxzA/ufbbqxB8_no.jpg',
#          'width': 1280,
#          'height': 720},
#         {'url': 'https://sun1-20.userapi.com/oSDUS8mIOZrx8ZhgzKDlHQpjEGT6NY7RgsvXMA/g0j20oYMGKI.jpg',
#          'width': 320,
#          'height': 180},
#         {'url': 'https://sun1-28.userapi.com/mREDnKX17x25KwRBuZdHCMXU5hSS2kvsCwALfw/F3DdXMyiLgo.jpg',
#          'width': 720,
#          'height': 405},
#         {'url': 'https://sun1-25.userapi.com/ZrTFpuA4XXD9-cDMNkStSaAhtHqQV4OXcWIFKA/fwZRkbYS_KA.jpg',
#          'width': 1024,
#          'height': 576},
#         {'url': 'https://sun1-19.userapi.com/Ad4nJK0i5jA8WOWdnIvPQ-YY3V0b1ApLI_9dkg/WF8-Sz7kceA.jpg',
#          'width': 4096,
#          'height': 2304}],
#        'first_frame': [{'url': 'https://i.mycdn.me/getVideoPreview?id=2347370220071&idx=0&type=39&tkn=wKdzGFxU8LLP9bWrzG9CRtFo7IQ&fn=vid_f',
#          'width': 720,
#          'height': 405},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2347370220071&idx=0&type=39&tkn=wKdzGFxU8LLP9bWrzG9CRtFo7IQ&fn=vid_md',
#          'width': 480,
#          'height': 270},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2347370220071&idx=0&type=39&tkn=wKdzGFxU8LLP9bWrzG9CRtFo7IQ&fn=vid_d',
#          'width': 240,
#          'height': 135},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2347370220071&idx=0&type=39&tkn=wKdzGFxU8LLP9bWrzG9CRtFo7IQ&fn=vid_sm',
#          'width': 128,
#          'height': 72},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2347370220071&idx=0&type=39&tkn=wKdzGFxU8LLP9bWrzG9CRtFo7IQ',
#          'width': 1280,
#          'height': 720},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2347370220071&idx=0&type=39&tkn=wKdzGFxU8LLP9bWrzG9CRtFo7IQ&fn=vid_h',
#          'width': 960,
#          'height': 540},
#         {'url': 'https://i.mycdn.me/getVideoPreview?id=2347370220071&idx=0&type=39&tkn=wKdzGFxU8LLP9bWrzG9CRtFo7IQ',
#          'width': 1280,
#          'height': 720}],
#        'width': 3840,
#        'height': 2160,
#        'id': 456240094,
#        'owner_id': -51890028,
#        'title': 'Как правильно строить предложения в английском. Простая схема.',
#        'is_favorite': False,
#        'track_code': 'video_e6ebc4afnrmdCGvFe14Cx2pya30IT5-SfXd5T74IHTZ98nPMst2kmoAPYqJ6WQLNYi1fSD59q6JNTk1LyWlxWg',
#        'repeat': 1,
#        'type': 'video',
#        'views': 17814}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 0, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 61, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 32, 'user_reposted': 0},
#     'views': {'count': 19443},
#     'hash': 'ksfRRASjTT_sMFlzDfVpYIbonv0'}]}}

# %% [markdown]
# ## Задание 3
#
# Выгрузи в переменную `posts` в формате датафрейма __все записи__ сообщества Skyeng: https://vk.com/skyeng,
#
# 1. Используй цикл `While`
# 2. Для выгрузки __всех записей__ тебе поможет параметр `offset`.
# 3. Записей больше 7000! Не забудь про ограничение "не больше 3 запросов в секунду" от API VK, здесь тебе поможет библиотека `time`

# %%
offset = 0
max_count = 100
posts = pd.DataFrame()

while True:      # Повторять цикл пока его не остановят по условию ниже
    
    url = 'https://api.vk.com/method/wall.get'
    params = {
        'access_token': token,
        'owner_id': '-' + str('51890028'),   # Таким интересным способом согласно документации передается ID группы
        'v':'5.103',
        'filter': 'all',
        'count': max_count,
        'offset': offset
        }
    
    req = requests.get(url=url, 
                       params=params)
    res = req.json()
    
    if len(res['response']['items']) != 0:      # Проверяем вернулись ли нам хоть какие-нибудь записи
        posts = pd.concat([posts, pd.DataFrame(res['response']['items'])]) 
    else:
        break                                   # Если нам ничего не вернулось, то прервать цикл
    print('Уже скачано', offset, 'записей')
    offset = offset + max_count                 # Смещаем offset на число возвращенных записей
    time.sleep(0.5)                             # Опять контролируем частоту запросов, чтобы нас не ограничили
# Out:
# Уже скачано 0 записей
# Уже скачано 100 записей
# Уже скачано 200 записей
# Уже скачано 300 записей
# Уже скачано 400 записей
# Уже скачано 500 записей
# Уже скачано 600 записей
# Уже скачано 700 записей
# Уже скачано 800 записей
# Уже скачано 900 записей
# Уже скачано 1000 записей
# Уже скачано 1100 записей
# Уже скачано 1200 записей
# Уже скачано 1300 записей
# Уже скачано 1400 записей
# Уже скачано 1500 записей
# Уже скачано 1600 записей
# Уже скачано 1700 записей
# Уже скачано 1800 записей
# Уже скачано 1900 записей
# Уже скачано 2000 записей
# Уже скачано 2100 записей
# Уже скачано 2200 записей
# Уже скачано 2300 записей
# Уже скачано 2400 записей
# Уже скачано 2500 записей
# Уже скачано 2600 записей
# Уже скачано 2700 записей
# Уже скачано 2800 записей
# Уже скачано 2900 записей
# Уже скачано 3000 записей
# Уже скачано 3100 записей
# Уже скачано 3200 записей
# Уже скачано 3300 записей
# Уже скачано 3400 записей
# Уже скачано 3500 записей
# Уже скачано 3600 записей
# Уже скачано 3700 записей
# Уже скачано 3800 записей
# Уже скачано 3900 записей
# Уже скачано 4000 записей
# Уже скачано 4100 записей
# Уже скачано 4200 записей
# Уже скачано 4300 записей
# Уже скачано 4400 записей
# Уже скачано 4500 записей
# Уже скачано 4600 записей
# Уже скачано 4700 записей
# Уже скачано 4800 записей
# Уже скачано 4900 записей
# Уже скачано 5000 записей
# Уже скачано 5100 записей
# Уже скачано 5200 записей
# Уже скачано 5300 записей
# Уже скачано 5400 записей
# Уже скачано 5500 записей
# Уже скачано 5600 записей
# Уже скачано 5700 записей
# Уже скачано 5800 записей
# Уже скачано 5900 записей
# Уже скачано 6000 записей
# Уже скачано 6100 записей
# Уже скачано 6200 записей
# Уже скачано 6300 записей
# Уже скачано 6400 записей
# Уже скачано 6500 записей
# Уже скачано 6600 записей
# Уже скачано 6700 записей
# Уже скачано 6800 записей
# Уже скачано 6900 записей
# Уже скачано 7000 записей
# Уже скачано 7100 записей
# Уже скачано 7200 записей
# Уже скачано 7300 записей
# Уже скачано 7400 записей
# Уже скачано 7500 записей
# Уже скачано 7600 записей
# Уже скачано 7700 записей
# Уже скачано 7800 записей
# Уже скачано 7900 записей
# Уже скачано 8000 записей
# Уже скачано 8100 записей

# %%
print('Кол-во записей:', len(posts))
# Out:
# Кол-во записей: 8162

# %%
posts.head()
# Out:
#       id   from_id  owner_id        date  marked_as_ads  is_favorite  \
# 0  88838 -51890028 -51890028  1657723336              0        False
# 1  88814 -51890028 -51890028  1657641379              0        False
# 2  88783 -51890028 -51890028  1657558914              0        False
# 3  88759 -51890028 -51890028  1657438405              0        False
# 4  88752 -51890028 -51890028  1657387800              0        False
#
#   post_type                                               text  \
# 0      post  Ваш гороскоп говорит, что сегодня отличный ден...
# 1      post  Спрашиваете своего друга, где он, и получаете ...
# 2      post  Совсем недавно вышел сериал Оби Ван Кеноби. По...
# 3      post
# 4      post  Среда — потому что в середине недели. Пятница ...
#
#                                          attachments     post_source  \
# 0  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}
# 1  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}
# 2  [{'type': 'video', 'video': {'access_key': '1b...  {'type': 'vk'}
# 3  [{'type': 'video', 'video': {'can_comment': 1,...  {'type': 'vk'}
# 4  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}
#
#                                             comments  \
# 0  {'can_post': 1, 'count': 4, 'groups_can_post':...
# 1  {'can_post': 1, 'count': 8, 'groups_can_post':...
# 2  {'can_post': 1, 'count': 0, 'groups_can_post':...
# 3  {'can_post': 1, 'count': 13, 'groups_can_post'...
# 4  {'can_post': 1, 'count': 5, 'groups_can_post':...
#
#                                                likes  \
# 0  {'can_like': 1, 'count': 25, 'user_likes': 0, ...
# 1  {'can_like': 1, 'count': 146, 'user_likes': 0,...
# 2  {'can_like': 1, 'count': 16, 'user_likes': 0, ...
# 3  {'can_like': 1, 'count': 30, 'user_likes': 0, ...
# 4  {'can_like': 1, 'count': 183, 'user_likes': 0,...
#
#                               reposts             views  \
# 0   {'count': 13, 'user_reposted': 0}   {'count': 4067}
# 1   {'count': 55, 'user_reposted': 0}  {'count': 14633}
# 2   {'count': 13, 'user_reposted': 0}   {'count': 6555}
# 3    {'count': 7, 'user_reposted': 0}  {'count': 11931}
# 4  {'count': 147, 'user_reposted': 0}  {'count': 22499}
#
#                           hash  edited copy_history  signer_id zoom_text  geo
# 0  9fkEpSeeXt8oqPS0Cpxz7teUOOY     NaN          NaN        NaN       NaN  NaN
# 1  Lclgutl8YtYmY9nia7fjr-WW7G8     NaN          NaN        NaN       NaN  NaN
# 2  akwkIDTD8i9NLuzvz7bM70DH23E     NaN          NaN        NaN       NaN  NaN
# 3  CBJUmCYHmw9lcO4fbgGrIUShiCI     NaN          NaN        NaN       NaN  NaN
# 4  XWQ04uAgJ4ENrZSL_zuiYX3amQM     NaN          NaN        NaN       NaN  NaN

# %% [markdown]
# ## Задание 4
#
# Выгрузи 50 самых популярных постов. Метрикой популярности мы считаем сумму лайков, репостов и комментариев.
#
# 1. Создай столбцы с числовыми значениями для лайков, репостов и комментариев и забери из словаря только значение по ключу `count`
# 2. Создай отдельный столбец, где будет сумма пользовательских активностей для каждого поста
# 3. Отсортируй дата-фрейм по столбцу с суммой пользовательских активностей
# 4. Выбери 50 самых популярных постов
#
# Если задание кажется легким, реализуй тот же код с `lambda` функцией.

# %%
# вытащи из словарей столбцов comments, likes, reposts только нужные значения

# заполни даными с прошлого шага новые столбцы
posts['comments_count'] = posts.comments.dropna().apply(lambda x: x.get('count', None))
posts['likes_count'] = posts.likes.dropna().apply(lambda x: x.get('count', None))
posts['reposts_count'] = posts.reposts.dropna().apply(lambda x: x.get('count', None))

# %%
posts.head()
# Out:
#       id   from_id  owner_id        date  marked_as_ads  is_favorite  \
# 0  88838 -51890028 -51890028  1657723336              0        False
# 1  88814 -51890028 -51890028  1657641379              0        False
# 2  88783 -51890028 -51890028  1657558914              0        False
# 3  88759 -51890028 -51890028  1657438405              0        False
# 4  88752 -51890028 -51890028  1657387800              0        False
#
#   post_type                                               text  \
# 0      post  Ваш гороскоп говорит, что сегодня отличный ден...
# 1      post  Спрашиваете своего друга, где он, и получаете ...
# 2      post  Совсем недавно вышел сериал Оби Ван Кеноби. По...
# 3      post
# 4      post  Среда — потому что в середине недели. Пятница ...
#
#                                          attachments     post_source  ...  \
# 0  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 1  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 2  [{'type': 'video', 'video': {'access_key': '1b...  {'type': 'vk'}  ...
# 3  [{'type': 'video', 'video': {'can_comment': 1,...  {'type': 'vk'}  ...
# 4  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
#
#               views                         hash edited copy_history  \
# 0   {'count': 4067}  9fkEpSeeXt8oqPS0Cpxz7teUOOY    NaN          NaN
# 1  {'count': 14633}  Lclgutl8YtYmY9nia7fjr-WW7G8    NaN          NaN
# 2   {'count': 6555}  akwkIDTD8i9NLuzvz7bM70DH23E    NaN          NaN
# 3  {'count': 11931}  CBJUmCYHmw9lcO4fbgGrIUShiCI    NaN          NaN
# 4  {'count': 22499}  XWQ04uAgJ4ENrZSL_zuiYX3amQM    NaN          NaN
#
#   signer_id  zoom_text  geo  comments_count likes_count reposts_count
# 0       NaN        NaN  NaN               4          25            13
# 1       NaN        NaN  NaN               8         146            55
# 2       NaN        NaN  NaN               0          16            13
# 3       NaN        NaN  NaN              13          30             7
# 4       NaN        NaN  NaN               5         183           147
#
# [5 rows x 23 columns]

# %%
# заполни данными столбец с суммой по всем активностям

posts['activity'] = posts['comments_count'] + posts['likes_count'] + posts['reposts_count']
posts.head()
# Out:
#       id   from_id  owner_id        date  marked_as_ads  is_favorite  \
# 0  88838 -51890028 -51890028  1657723336              0        False
# 1  88814 -51890028 -51890028  1657641379              0        False
# 2  88783 -51890028 -51890028  1657558914              0        False
#
#   post_type                                               text  \
# 0      post  Ваш гороскоп говорит, что сегодня отличный ден...
# 1      post  Спрашиваете своего друга, где он, и получаете ...
# 2      post  Совсем недавно вышел сериал Оби Ван Кеноби. По...
#
#                                          attachments     post_source  ...  \
# 0  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 1  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 2  [{'type': 'video', 'video': {'access_key': '1b...  {'type': 'vk'}  ...
#
#                           hash edited copy_history signer_id zoom_text  geo  \
# 0  9fkEpSeeXt8oqPS0Cpxz7teUOOY    NaN          NaN       NaN       NaN  NaN
# 1  Lclgutl8YtYmY9nia7fjr-WW7G8    NaN          NaN       NaN       NaN  NaN
# 2  akwkIDTD8i9NLuzvz7bM70DH23E    NaN          NaN       NaN       NaN  NaN
#
#   comments_count  likes_count reposts_count activity
# 0              4           25            13       42
# 1              8          146            55      209
# 2              0           16            13       29
#
# [3 rows x 24 columns]

# %%
# Отсортируй дата-фрейм по столбцу с суммой пользовательских активностей
# Выбери 50 самых популярных постов

posts = posts.sort_values(['activity'],ascending=False)

top_posts = posts.head(50)
top_posts.reset_index()
# Out:
#     index     id   from_id  owner_id        date  marked_as_ads  is_favorite  \
# 0      61  63081 -51890028 -51890028  1602590409              0        False
# 1       8  25259 -51890028 -51890028  1554800244              0        False
# 2      55    977 -51890028 -51890028  1416930109              0        False
# 3      96  75933 -51890028 -51890028  1604923204              0        False
# 4      87  42960 -51890028 -51890028  1568444249              0        False
# 5      52  48883 -51890028 -51890028  1574414757              0        False
# 6      59  31067 -51890028 -51890028  1561301735              0        False
# 7      92  55740 -51890028 -51890028  1587207600              0        False
# 8      20  51793 -51890028 -51890028  1581057787              0        False
# 9      46  57606 -51890028 -51890028  1589373062              0        False
# 10     12  60584 -51890028 -51890028  1596104809              0        False
# 11     53  46599 -51890028 -51890028  1569916801              0        False
# 12     56  53495 -51890028 -51890028  1583935214              0        False
# 13     84  61198 -51890028 -51890028  1597644180              0        False
# 14     41  49309 -51890028 -51890028  1574838003              0        False
# 15      7  58506 -51890028 -51890028  1591446471              0        False
# 16     78   1955 -51890028 -51890028  1424708125              0        False
# 17     55  53529 -51890028 -51890028  1583942411              0        False
# 18     57  59728 -51890028 -51890028  1593871472              0        False
# 19     67  29630 -51890028 -51890028  1560929039              0        False
# 20     83  80953 -51890028 -51890028  1609318604              0        False
# 21     10   1071 -51890028 -51890028  1417540800              0        False
# 22     36  49521 -51890028 -51890028  1575036060              0        False
# 23     97  52465 -51890028 -51890028  1582095606              0        False
# 24     76  83458 -51890028 -51890028  1614434940              0        False
# 25     34  54766 -51890028 -51890028  1585118114              0        False
# 26     96  50315 -51890028 -51890028  1576914557              0        False
# 27      8  82904 -51890028 -51890028  1613116047              0        False
# 28     73  83507 -51890028 -51890028  1614590078              0        False
# 29     36  87914 -51890028 -51890028  1655394926              0        False
# 30     71  56848 -51890028 -51890028  1588256830              0        False
# 31     86  25874 -51890028 -51890028  1555683420              0        False
# 32     42  61837 -51890028 -51890028  1599653403              0        False
# 33     57  83644 -51890028 -51890028  1615298700              0        False
# 34     83  59310 -51890028 -51890028  1592669785              0        False
# 35     62  30758 -51890028 -51890028  1561130880              0        False
# 36     63  57238 -51890028 -51890028  1588573020              0        False
# 37     16  41520 -51890028 -51890028  1567234808              0        False
# 38     55  81596 -51890028 -51890028  1611040740              0        False
# 39      2  58770 -51890028 -51890028  1591704289              0        False
# 40     39   5078 -51890028 -51890028  1450178421              0        False
# 41      4  80671 -51890028 -51890028  1608657060              0        False
# 42     73  61440 -51890028 -51890028  1598247960              0        False
# 43     54  23617 -51890028 -51890028  1552739280              0        False
# 44     75  28925 -51890028 -51890028  1560611851              0        False
# 45     98  83020 -51890028 -51890028  1613550503              0        False
# 46     74  59439 -51890028 -51890028  1593012000              0        False
# 47      6  25267 -51890028 -51890028  1554805320              0        False
# 48      6  84862 -51890028 -51890028  1622707174              0        False
# 49     80  59374 -51890028 -51890028  1592829812              0        False
#
#    post_type                                               text  \
# 0       post  КОНКУРС! Выиграйте уроки английского и бьюти-б...
# 1       post  Через 15 дней вы накачаете пресс и выучите анг...
# 2       post  100 полезных английских фраз\nЭти фразы выруча...
# 3       post  КОНКУРС! Выиграйте уроки английского и боксы с...
# 4       post  😑Предлоги в английском — больная тема для всех...
# 5       post  Кот Виктор показывает, как стал причиной сканд...
# 6       post  Играем в слова. У кого словарный запас больше?...
# 7       post  Без фразовых глаголов можно понимать только са...
# 8       post  Английский снова сводит нас с ума, 😉и ему вооб...
# 9       post  Готовы ли вы к жизни в англоговорящем городе? ...
# 10      post            Подписывайтесь на [club51890028|Skyeng]
# 11      post                                 📚🤓Ну вы поняли.👇🏻😉
# 12      post
# 13      post  Все самые главные фразовые глаголы в карточках...
# 14      post  Методисты онлайн-школы Skyeng составили чек-ли...
# 15      post  Простое объяснение всех времен в английском. \...
# 16      post  60 английских фраз на все случаи жизни\nТакого...
# 17      post  🎁 Ребят, мы тут конкурс затеяли. Подарим 2 БЕС...
# 18      post  58 фразовых глаголов на все случаи жизни! \n\n...
# 19      post  Теперь вы знаете, как отвечать:\n– How are you...
# 20      post  Новогодний словарик: 36 праздничных английских...
# 21      post  100 английских фраз для путешествий\nЭти фразы...
# 22      post  ✅Приставки открывают сразу много новых слов пр...
# 23      post  Наши методисты составили чек-лист: какие темы ...
# 24      post  58 фразовых глаголов 🔥🇬🇧\n\nМы собрали в одну ...
# 25      post                                      👉 Без паники!
# 26      post  Skyeng объясняет как не запутаться в английско...
# 27      post  5 важных предлогов в английском 🔥🇬🇧\n\nПредлог...
# 28      post  Не путайте предлоги: полезные карточки 🇬🇧📌\n\n...
# 29      post  Чем заменить надоевшее «How are you?» \n\nМы с...
# 30      post  Идея на майские.💡80 иностранных фильмов для пр...
# 31      post  Раз в неделю, мы и [club130552184|Topsify] пре...
# 32      post  Английские предлоги не поддаются каким-либо пр...
# 33      post  Синонимы к фразе «I like» 😍 Сохраняйте себе и ...
# 34      post  Синонимы к прилагательным happy, good и beauti...
# 35      post  Мы любим разбирать Карди Би. Это как будто выу...
# 36      post  Хвалите себя чаще! \n\n❓ Расскажите, как вы пр...
# 37      post  😃Билли Айлиш проспала премию Video Music Award...
# 38      post  В чем разница между словами say, tell, speak и...
# 39      post  Напишите в комментариях цифру от 1 до 7. Фраза...
# 40      post  Skyeng Steps — бесплатный курс разговорного ан...
# 41      post  5 самых важных времен в английском \n\nВ англи...
# 42      post  Английские синонимы, в которых уже заложено ус...
# 43      post  Дэни собрал для вас самый топовый американский...
# 44      post  Вы можете учить английский вообще бесплатно и ...
# 45      post  В чем разница между must и should? А когда исп...
# 46      post               В вашу видео-копилку на выходные. 👇🏻
# 47      post  Дэни собрал для вас самый топовый американский...
# 48      post  Английские предлоги не поддаются каким-либо пр...
# 49      post  Фразовые глаголы со словом get, которые должен...
#
#                                           attachments  ...  \
# 0   [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 1   [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 2   [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 3   [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 4   [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 5   [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 6   [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 7   [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 8   [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 9   [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 10  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 11  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 12  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 13  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 14  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 15  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 16  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 17  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 18  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 19  [{'type': 'video', 'video': {'access_key': 'bb...  ...
# 20  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 21  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 22  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 23  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 24  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 25  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 26  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 27  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 28  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 29  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 30  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 31  [{'type': 'link', 'link': {'url': 'https://m.v...  ...
# 32  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 33  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 34  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 35  [{'type': 'link', 'link': {'url': 'https://m.v...  ...
# 36  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 37  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 38  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 39  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 40  [{'type': 'link', 'link': {'url': 'http://scho...  ...
# 41  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 42  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 43  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 44  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 45  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 46  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 47  [{'type': 'doc', 'doc': {'id': 497691275, 'own...  ...
# 48  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
# 49  [{'type': 'photo', 'photo': {'album_id': -7, '...  ...
#
#                            hash        edited copy_history signer_id  \
# 0   bk2bwJWmyPQyqGWGj7RR4MUsqdQ           NaN          NaN       NaN
# 1   txbcMqs7GOKFMSJq8A5lFbeoJpQ  1.554800e+09          NaN       NaN
# 2   a_pFvGW4h5DrDfy0fRlfOsg9dsE  1.416991e+09          NaN       NaN
# 3   Owc3Fg3SI1j_078k8ekzcqKhcVE           NaN          NaN       NaN
# 4   -FO6dIkZxcpGnqo5ILofBZNn1RQ  1.568449e+09          NaN       NaN
# 5   9FbAwJsuCtmzsI3OmaDF8GelwvM           NaN          NaN       NaN
# 6   LaXE--Rn0eqQ6CZYMaR77uE009g  1.561308e+09          NaN       NaN
# 7   gSad10qG1FeiSjRjI389Eu9iRB4           NaN          NaN       NaN
# 8   k7jbX-B_wH7lb_FEgvHnhI7ZmcQ  1.581063e+09          NaN       NaN
# 9   uWhbOLIa2TDYUYAkmf-FL5Nkxbw           NaN          NaN       NaN
# 10  N45rW8LgU_hqUJwui45HSWO3svo  1.596128e+09          NaN       NaN
# 11  2NwGvhUr3_bDoo1D_bu4CZWgFMg           NaN          NaN       NaN
# 12  lCBEbJG8rzj6MEgGQJExB5QubEs           NaN          NaN       NaN
# 13  NznpdsJrBvxsV9IXqkuEQ_lsVZc           NaN          NaN       NaN
# 14  0voj9Qopf-FH0oHh2YHyhnKrKmE  1.574869e+09          NaN       NaN
# 15  NbpX4pC_G-YKcqPDzUZaZelXSJE           NaN          NaN       NaN
# 16  lhoIJiByHGH3B9FwnGiWlxZg-B0           NaN          NaN       NaN
# 17  AaPTgb5mtmVo6-f_LCVEf17ZfrA  1.583951e+09          NaN       NaN
# 18  oKAGzDlJX8_A5g58veJXkvKm5NY           NaN          NaN       NaN
# 19  Ra9n4pt9xjkoQiSDEsUxytWX5N4  1.560929e+09          NaN       NaN
# 20  oyuI0d53H94KChUno29W1HXbhdQ           NaN          NaN       NaN
# 21  1sJL4cDZDXxP0AGnHx24g2Eu6q8           NaN          NaN       NaN
# 22  c0eRIbdfL579j7JdNIx-7qk8lrk  1.575041e+09          NaN       NaN
# 23  RQw__kE04KGbYdU1LUakrj98U64           NaN          NaN       NaN
# 24  IcZTKVeTLjShzt_Lo3mwE7JX9ko           NaN          NaN       NaN
# 25  rXRLQa4idR1AkoebX3VNKD_SoiQ           NaN          NaN       NaN
# 26  Mp_wyuDHgf2-vN_P4J8hwi-c5Wk           NaN          NaN       NaN
# 27  ySJ7aM3V9xk1aDlyDKB8LsCGV_U           NaN          NaN       NaN
# 28  30q3z7bSDaOJFkV2ss0RXDoWdcQ           NaN          NaN       NaN
# 29  M0y1-76BRh6EBv9iKX5zoWxbCw0           NaN          NaN       NaN
# 30  0IBCPPd-WoNLZZX6L3j4VthOXAo  1.588258e+09          NaN       NaN
# 31  5ETbF1cJt7cyxHHFl8XfExr1AmY  1.555690e+09          NaN       NaN
# 32  mWFYFktyfNbzKzR0wEDwVXTYdO4           NaN          NaN       NaN
# 33  7TWqojWfKiZwwh5hLRXqJlhQq_A           NaN          NaN       NaN
# 34  4cOyZFJSyPb5v298EphiWamw2s4           NaN          NaN       NaN
# 35  DUEDyFvupiS0ukGgQG3psncThmI           NaN          NaN       NaN
# 36  fxxuPx_ln61YRaLQAq_dJG2idi8           NaN          NaN       NaN
# 37  qijX9C8aFVH7MmHJYa9dWXQILYI           NaN          NaN       NaN
# 38  BXqDMdvsLPrt6Gks9jiWIhs6LcQ           NaN          NaN       NaN
# 39  cEOk2Z6u4NDw44Y64jmcS5QqQpg  1.591706e+09          NaN       NaN
# 40  mzuUTUlJPgRKAnb-aSPAwFqxN7I           NaN          NaN       NaN
# 41  -XdDI--hZG480KpykOBOHb4Ca4o           NaN          NaN       NaN
# 42  ReFW59KJV5aLkCZw3ZLIz5N9HqA           NaN          NaN       NaN
# 43  Ao5n0oi1H_aAXeUm5a8okDCjXNM           NaN          NaN       NaN
# 44  59ZDlxLgPTiI-yi-cShqfFJd3yg           NaN          NaN       NaN
# 45  -Xi524iwTFGZs0KPt-3LzGb8djM           NaN          NaN       NaN
# 46  Dh8iCXyJSG7xC7hYlTbnIOsTvTU           NaN          NaN       NaN
# 47  IovTjBBLG_kdDIbMDAn4d2mhocU           NaN          NaN       NaN
# 48  QF4wN8N0Ax9wRxxEoQHLScSi2OA           NaN          NaN       NaN
# 49  Gekc4JZa9XNnHtvFVDs6xDqtxu4  1.592854e+09          NaN       NaN
#
#    zoom_text  geo  comments_count likes_count  reposts_count activity
# 0        NaN  NaN           10962         117              2    11081
# 1        NaN  NaN             239        7005           1345     8589
# 2        NaN  NaN               0        4012            973     4985
# 3        NaN  NaN            2891         133              6     3030
# 4        NaN  NaN              50        1931            445     2426
# 5        NaN  NaN              54        1623            203     1880
# 6        NaN  NaN            1634         135              3     1772
# 7        NaN  NaN              36        1398            272     1706
# 8        NaN  NaN             111        1383            197     1691
# 9        NaN  NaN              84        1479            115     1678
# 10       NaN  NaN              26        1458            156     1640
# 11       NaN  NaN              44        1426             81     1551
# 12       NaN  NaN              66        1423             57     1546
# 13       NaN  NaN              18        1207            233     1458
# 14       NaN  NaN              35        1175            231     1441
# 15       NaN  NaN             104        1186            140     1430
# 16       NaN  NaN               0        1059            230     1289
# 17       NaN  NaN             661         586              8     1255
# 18       NaN  NaN              69         955            203     1227
# 19       NaN  NaN             132        1024             31     1187
# 20       NaN  NaN               0         655            517     1172
# 21       NaN  NaN               0         883            273     1156
# 22       NaN  NaN               8         907            184     1099
# 23       NaN  NaN              26         889            173     1088
# 24       NaN  NaN               3         518            526     1047
# 25       NaN  NaN              38         893             27      958
# 26       NaN  NaN              20         827             99      946
# 27       NaN  NaN               8         474            457      939
# 28       NaN  NaN               0         455            477      932
# 29       NaN  NaN               7         531            366      904
# 30       NaN  NaN              47         727            121      895
# 31       NaN  NaN              27         811             26      864
# 32       NaN  NaN               6         703            139      848
# 33       NaN  NaN              11         569            258      838
# 34       NaN  NaN              10         694            128      832
# 35       NaN  NaN              79         696             53      828
# 36       NaN  NaN              22         719             70      811
# 37       NaN  NaN              58         727             24      809
# 38       NaN  NaN               2         443            364      809
# 39       NaN  NaN              74         664             71      809
# 40       NaN  NaN               0         658            133      791
# 41       NaN  NaN               0         396            381      777
# 42       NaN  NaN               9         664            102      775
# 43       NaN  NaN              28         673             72      773
# 44       NaN  NaN             196         557              2      755
# 45       NaN  NaN              32         393            329      754
# 46       NaN  NaN              32         654             63      749
# 47       NaN  NaN              41         643             52      736
# 48       NaN  NaN               0         361            374      735
# 49       NaN  NaN              11         622             99      732
#
# [50 rows x 25 columns]

# %% [markdown]
# ## Задание 5
#
# __Почисти данные, сохрани результат в файл для отправки копирайтерам__
#
# 1. Отфильтруй в датафрейме только нужные столбцы:
#     - дата поста
#     - текст поста
#     - количество комментариев
#     - количество лайков
#     - количество репостов
#     - общее количество пользовательских активностей
#
# 2. Выгрузи датафрейм в .csv файл

# %%
top_posts = top_posts[['date', 'text', 'comments_count', 'likes_count', 'reposts_count', 'activity']]
top_posts
# Out:
#           date                                               text  \
# 61  1602590409  КОНКУРС! Выиграйте уроки английского и бьюти-б...
# 8   1554800244  Через 15 дней вы накачаете пресс и выучите анг...
# 55  1416930109  100 полезных английских фраз\nЭти фразы выруча...
# 96  1604923204  КОНКУРС! Выиграйте уроки английского и боксы с...
# 87  1568444249  😑Предлоги в английском — больная тема для всех...
# 52  1574414757  Кот Виктор показывает, как стал причиной сканд...
# 59  1561301735  Играем в слова. У кого словарный запас больше?...
# 92  1587207600  Без фразовых глаголов можно понимать только са...
# 20  1581057787  Английский снова сводит нас с ума, 😉и ему вооб...
# 46  1589373062  Готовы ли вы к жизни в англоговорящем городе? ...
# 12  1596104809            Подписывайтесь на [club51890028|Skyeng]
# 53  1569916801                                 📚🤓Ну вы поняли.👇🏻😉
# 56  1583935214
# 84  1597644180  Все самые главные фразовые глаголы в карточках...
# 41  1574838003  Методисты онлайн-школы Skyeng составили чек-ли...
# 7   1591446471  Простое объяснение всех времен в английском. \...
# 78  1424708125  60 английских фраз на все случаи жизни\nТакого...
# 55  1583942411  🎁 Ребят, мы тут конкурс затеяли. Подарим 2 БЕС...
# 57  1593871472  58 фразовых глаголов на все случаи жизни! \n\n...
# 67  1560929039  Теперь вы знаете, как отвечать:\n– How are you...
# 83  1609318604  Новогодний словарик: 36 праздничных английских...
# 10  1417540800  100 английских фраз для путешествий\nЭти фразы...
# 36  1575036060  ✅Приставки открывают сразу много новых слов пр...
# 97  1582095606  Наши методисты составили чек-лист: какие темы ...
# 76  1614434940  58 фразовых глаголов 🔥🇬🇧\n\nМы собрали в одну ...
# 34  1585118114                                      👉 Без паники!
# 96  1576914557  Skyeng объясняет как не запутаться в английско...
# 8   1613116047  5 важных предлогов в английском 🔥🇬🇧\n\nПредлог...
# 73  1614590078  Не путайте предлоги: полезные карточки 🇬🇧📌\n\n...
# 36  1655394926  Чем заменить надоевшее «How are you?» \n\nМы с...
# 71  1588256830  Идея на майские.💡80 иностранных фильмов для пр...
# 86  1555683420  Раз в неделю, мы и [club130552184|Topsify] пре...
# 42  1599653403  Английские предлоги не поддаются каким-либо пр...
# 57  1615298700  Синонимы к фразе «I like» 😍 Сохраняйте себе и ...
# 83  1592669785  Синонимы к прилагательным happy, good и beauti...
# 62  1561130880  Мы любим разбирать Карди Би. Это как будто выу...
# 63  1588573020  Хвалите себя чаще! \n\n❓ Расскажите, как вы пр...
# 16  1567234808  😃Билли Айлиш проспала премию Video Music Award...
# 55  1611040740  В чем разница между словами say, tell, speak и...
# 2   1591704289  Напишите в комментариях цифру от 1 до 7. Фраза...
# 39  1450178421  Skyeng Steps — бесплатный курс разговорного ан...
# 4   1608657060  5 самых важных времен в английском \n\nВ англи...
# 73  1598247960  Английские синонимы, в которых уже заложено ус...
# 54  1552739280  Дэни собрал для вас самый топовый американский...
# 75  1560611851  Вы можете учить английский вообще бесплатно и ...
# 98  1613550503  В чем разница между must и should? А когда исп...
# 74  1593012000               В вашу видео-копилку на выходные. 👇🏻
# 6   1554805320  Дэни собрал для вас самый топовый американский...
# 6   1622707174  Английские предлоги не поддаются каким-либо пр...
# 80  1592829812  Фразовые глаголы со словом get, которые должен...
#
#     comments_count  likes_count  reposts_count  activity
# 61           10962          117              2     11081
# 8              239         7005           1345      8589
# 55               0         4012            973      4985
# 96            2891          133              6      3030
# 87              50         1931            445      2426
# 52              54         1623            203      1880
# 59            1634          135              3      1772
# 92              36         1398            272      1706
# 20             111         1383            197      1691
# 46              84         1479            115      1678
# 12              26         1458            156      1640
# 53              44         1426             81      1551
# 56              66         1423             57      1546
# 84              18         1207            233      1458
# 41              35         1175            231      1441
# 7              104         1186            140      1430
# 78               0         1059            230      1289
# 55             661          586              8      1255
# 57              69          955            203      1227
# 67             132         1024             31      1187
# 83               0          655            517      1172
# 10               0          883            273      1156
# 36               8          907            184      1099
# 97              26          889            173      1088
# 76               3          518            526      1047
# 34              38          893             27       958
# 96              20          827             99       946
# 8                8          474            457       939
# 73               0          455            477       932
# 36               7          531            366       904
# 71              47          727            121       895
# 86              27          811             26       864
# 42               6          703            139       848
# 57              11          569            258       838
# 83              10          694            128       832
# 62              79          696             53       828
# 63              22          719             70       811
# 16              58          727             24       809
# 55               2          443            364       809
# 2               74          664             71       809
# 39               0          658            133       791
# 4                0          396            381       777
# 73               9          664            102       775
# 54              28          673             72       773
# 75             196          557              2       755
# 98              32          393            329       754
# 74              32          654             63       749
# 6               41          643             52       736
# 6                0          361            374       735
# 80              11          622             99       732

# %%
top_posts.to_csv('top_posts.csv', index=False)
